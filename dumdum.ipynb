# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
from ss.dataset import LibriSpeechMixedDataset

# %%
# Prepare train dataset

dataset = LibriSpeechMixedDataset(
    split='train',
    speakers_dataset='/home/dzhunk/University/dl-audio/speaker_separation/data/librispeech/train-clean-100',
    path_mixtures='/home/dzhunk/University/dl-audio/speaker_separation/data/mixes/train-clean-100',
    snr_levels=[-5, -2.5, 0, 2.5, 5],
    update_steps=100,
    trim_db=20,
    vad_db=20,
    audio_len=4,
    n_mixes=30000
)
# Out:
# /home/dzhunk/University/dl-audio/speaker_separation/.venv/lib/python3.10/site-packages/pyloudnorm/normalize.py:62: UserWarning: Possible clipped samples in output.
#   warnings.warn("Possible clipped samples in output.")
# /home/dzhunk/University/dl-audio/speaker_separation/.venv/lib/python3.10/site-packages/pyloudnorm/normalize.py:62: UserWarning: Possible clipped samples in output.
#   warnings.warn("Possible clipped samples in output.")
# /home/dzhunk/University/dl-audio/speaker_separation/.venv/lib/python3.10/site-packages/pyloudnorm/normalize.py:62: UserWarning: Possible clipped samples in output.
#   warnings.warn("Possible clipped samples in output.")
# /home/dzhunk/University/dl-audio/speaker_separation/.venv/lib/python3.10/site-packages/pyloudnorm/normalize.py:62: UserWarning: Possible clipped samples in output.
#   warnings.warn("Possible clipped samples in output.")
# ...

# %%
dataset = LibriSpeechMixedDataset(
    split='val',
    speakers_dataset='/home/dzhunk/University/dl-audio/speaker_separation/data/librispeech/test-clean',
    path_mixtures='/home/dzhunk/University/dl-audio/speaker_separation/data/mixes/test-clean',
    snr_levels=[0],
    update_steps=100,
    trim_db=20,
    vad_db=20,
    audio_len=4,
    n_mixes=2000
)
# Out:
# /home/dzhunk/University/dl-audio/speaker_separation/.venv/lib/python3.10/site-packages/pyloudnorm/normalize.py:62: UserWarning: Possible clipped samples in output.
#   warnings.warn("Possible clipped samples in output.")
# /home/dzhunk/University/dl-audio/speaker_separation/.venv/lib/python3.10/site-packages/pyloudnorm/normalize.py:62: UserWarning: Possible clipped samples in output.
#   warnings.warn("Possible clipped samples in output.")
# /home/dzhunk/University/dl-audio/speaker_separation/.venv/lib/python3.10/site-packages/pyloudnorm/normalize.py:62: UserWarning: Possible clipped samples in output.
#   warnings.warn("Possible clipped samples in output.")
# /home/dzhunk/University/dl-audio/speaker_separation/.venv/lib/python3.10/site-packages/pyloudnorm/normalize.py:62: UserWarning: Possible clipped samples in output.
#   warnings.warn("Possible clipped samples in output.")
# ...

# %%
import os

os.path.split('/home/dzhunk/University/dl-audio/speaker_separation/data/mixes/test-clean/61_121_001896-mixed.wav')[-1].split('-')[0].split('_')[-1]
# Out:
# '001896'

# %%
a = ('a', 'b', 'c', 'd')
a
# Out:
# ('a', 'b', 'c', 'd')

# %%
a[0:2]
# Out:
# ('a', 'b')
