# %%
# !git clone

# %%
import os

os.environ['WANDB_API_KEY'] =

# %%
from IPython.display import clear_output

# %%
# !pip install torch-audiomentations
# !pip install pyloudnorm
# !pip install pesq

# %%
# !cd speaker_separation ; python train.py --config /kaggle/working/speaker_separation/ss/configs/spexp.json
